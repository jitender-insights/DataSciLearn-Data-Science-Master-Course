# %% [markdown]
# # Functions in Python
#
# - Functions are used to well organized our code and enhance code readability and resuability.
# - In Python,a function is defined using the def keyword.
# - A function can return some value,or not depending upon its use case.
# - If it has to return a value , the return statement.
# - We can add as many parameters as we want. Parameters must be separated with a comma.
# - In Python, a function or may not return data.
#
#
# ### Parameter VS Argument
#
# - A Parameter is the variable listed inside the paraentheses() in the function definition.
# - An argument is the value that is sent to the function when it is called
#
#
# ![image.png](attachment:image.png)

# %%
print("this is my print function")
# Out:
# this is my print function

# %%
type(print())
# Out:
# NoneType

# %%
l =[3,5,6,7,8,9]
len(l)
# Out:
# 6

# %%
type(l)
# Out:
# list

# %%
def test():    #syntax of a function is - def is a keyword - def - defining a function - test()-function name
    print("Hello Python Lovers")

# %%
test()   #to call a function we need to call with the function name
# Out:
# Hello Python Lovers

# %%
def test1():  
    #Empty function
    pass

# %%
test() + 'DataScience'
# Out:
# Hello Python Lovers
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\3058705102.py in <module>
# ----> 1 test() + 'DataScience'
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
    return "Data Science Master "

# %%
test2()
# Out:
# 'Data Science Master '

# %%
type(test2())
# Out:
# str

# %%
test2() + 'machineleanring'
# Out:
# 'Data Science Master machineleanring'

# %%
def my_func():
    return 'aws',25,5.7,True,[2,4,5,6]

# %%
my_func()
# Out:
# ('aws', 25, 5.7, True, [2, 4, 5, 6])

# %%
a,b,c,d,e=my_func()

# %%
a
# Out:
# 'aws'

# %%
b
# Out:
# 25

# %%
c
# Out:
# 5.7

# %%
d
# Out:
# True

# %%
e
# Out:
# [2, 4, 5, 6]

# %%
def test4():
    m = 5*6/6
    return m

# %%
test4()
# Out:
# 5.0

# %%
def test5():
    m = 5+6/7
    return m

# %%
test5()
# Out:
# 5.857142857142857

# %%
def test5(m,n,o):
    a = m+n/o
    return a

# %%
test5()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\379652043.py in <module>
# ----> 1 test5()
#
# TypeError: test5() missing 3 required positional arguments: 'm', 'n', and 'o'

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def square(n) : # function to find a square of a number 
    n = n*n
    return n
square(10)
# Out:
# 100

# %%
def even_odd(num): 
    
    """" This function will check whether a number is even or odd"""
    
    if num % 2 ==0:
        print(num,'is even number')
    else :
        print(num,'is odd number')
        
even_odd(7)
even_odd(6)
print(even_odd.__doc__)  #print function documentation string
# Out:
# 7 is odd number
# 6 is even number
# " This function will check whether a number is even or odd

# %%
def test6(a,b):
    return a+b

# %%
test6(4,5)
# Out:
# 9

# %%
test6('ml',' datascience')
# Out:
# 'ml datascience'

# %%
test6([12,32,4,9],[4,5,76,7,8])
# Out:
# [12, 32, 4, 9, 4, 5, 76, 7, 8]

# %%
def fullname(firstname,middlename,lastname): #Concatenate Strings
    
    fullname= "{} {} {}".format(firstname,middlename,lastname)
    print(fullname)
fullname('Mohit','Singh','Rajput')
# Out:
# Mohit Singh Rajput

# %% [markdown]
# # Global and Local Variables

# %%
var1 = 100   #Variable with Global Scope 

def myfunc():
    print(var1)
myfunc()
print(var1)
# Out:
# 100
# 100

# %%
def myfunc1():
    var2 = 10    #variable with local scope
    print(var2)
    
def myfunc2():
    
    print(var2)
    
myfunc1()
myfunc2()
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\3969638827.py in <module>
#       8
#       9 myfunc1()
# ---> 10 myfunc2()
#      11
#      12
#
# ~\AppData\Local\Temp\ipykernel_16716\3969638827.py in myfunc2()
#       5 def myfunc2():
#       6
# ----> 7     print(var2)
#       8
#       9 myfunc1()
#
# NameError: name 'var2' is not defined

# %%
var1 = 100  # Variable with a Global scope
 
def myfunc():
    var1 = 99 # Local Variable 
    print(var1)
    
myfunc()
print(var1)
# Out:
# 99
# 100

# %%
l = [1,2,3,4,'aws','kde',[1,2,3,5,7,6]]

# %%
l1 = []
for i in l :
    if type(i) == int or type(i) == float :
        l1.append(i)
print(l1)
# Out:
# [1, 2, 3, 4]

# %%
def test7(l):
    l1 = []
    for i in l :
        if type(i) == int or type(i) == float :
            l1.append(i)
    return l1

# %%
test7(l1)
# Out:
# [1, 2, 3, 4]

# %%
def test10(a,b):
    return a+b

# %%
test10(7,8,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\4185464494.py in <module>
# ----> 1 test10(7,8,9)
#
# TypeError: test10() takes 2 positional arguments but 3 were given

# %% [markdown]
# ### args & kwargs
#
# *args
#
# - When we are not sure about the number of arguments being passed to a function then we can use *args as function parameter.
# - *args allow us to pass the variable number of Non Keyword Arguments to a function
# - The argument are always passed as a tuple
#
# **kwargs
# - **kwargs allows us to pass the variable number of Keyword Arguments to the function.
# - We can simply use an double asterik ** before the parameter name to pass variable lenght arguments.
# - The argumnets are passed as a dictionary

# %%
def test11(*args):
    return args

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3)

# %%
test11(1,2,3,'aws','ml',[1,2,3,43,54,5])
# Out:
# (1, 2, 3, 'aws', 'ml', [1, 2, 3, 43, 54, 5])

# %%
def test12(*datascience):
    return datascience

# %%
test12(3.6,8.0,'deeplearning',True)
# Out:
# (3.6, 8.0, 'deeplearning', True)

# %%
def test13(*args,a):
    return args,a
test13(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\3467022007.py in <module>
#       1 def test13(*args,a):
#       2     return args,a
# ----> 3 test13(1,2,3,4)
#
# TypeError: test13() missing 1 required keyword-only argument: 'a'

# %%
test13(1,2,3,4,a=24)
# Out:
# ((1, 2, 3, 4), 24)

# %%
def test14(c,d,a=23,b=1):
    return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\3076521518.py in <module>
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=243)
# Out:
# (243, 1, 2, 5)

# %%
def test15(**kwargs):
    return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,34,45],b='python',c=3.66677)
# Out:
# {'a': [1, 2, 34, 45], 'b': 'python', 'c': 3.66677}
