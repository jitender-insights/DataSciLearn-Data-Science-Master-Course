# %% [markdown]
# # DICTIONARIES IN PYTHON
#
# 1. Dictionaries are used to store data values in key:value pairs.
# 2. A dictionary is a collection which is ordered, changeable or mutable and do not allow duplicates.
# 3. Dictionary items are ordered, changeable, and does not allow duplicates.
# 4. Dictionary items are presented in key:value pairs, and can be referred to by using the key name.
# 5. Dictionaries are changeable, meaning that we can change, add or remove items after the dictionary has
#    been created.
# 6. Dictionaries cannot have two items with the same key.
# 7. A dictionary can nested and can contain another dictionary.
#
# ![image.png](attachment:image.png)

# %%
d1 = {'name' : 'Bob'}
print(d1)
# Out:
# {'name': 'Bob'}

# %%
d2 = {'age' : 45}
print(d2)
# Out:
# {'age': 45}

# %%
print(type(d2))
# Out:
# <class 'dict'>

# %%
d = {}   #empty dict or empty set
print(type(d))
# Out:
# <class 'dict'>

# %%
d3 = {'name':'John', 'age' : 25, 'email_id':'john@gmail.com' ,'city' : 'New York'}
print(d3)
# Out:
# {'name': 'John', 'age': 25, 'email_id': 'john@gmail.com', 'city': 'New York'}

# %%
d4 = {'course':['aws', 'cloud','ml']}
d4
# Out:
# {'course': ['aws', 'cloud', 'ml']}

# %%
d5 = {'course':['deeplearning','machinelearning','nlp','nlp']}
d5
# Out:
# {'course': ['deeplearning', 'machinelearning', 'nlp', 'nlp']}

# %%
d6 = {'key':'youtube','key':'youtube'}
print(d6)
# Out:
# {'key': 'youtube'}

# %% [markdown]
# # Indexing in dict

# %%
d3
# Out:
# {'name': 'John', 'age': 25, 'email_id': 'john@gmail.com', 'city': 'New York'}

# %%
d3['age']
# Out:
# 25

# %%
d3[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19888\791329364.py in <module>
# ----> 1 d3[1]
#
# KeyError: 1

# %%
d3['city']
# Out:
# 'New York'

# %%
d3['email_id']
# Out:
# 'john@gmail.com'

# %%
d7 = {'company':['tata','birla','infosys','ril'],'projects':('ds','ml','nlp'), 'best':'abc'}
d7
# Out:
# {'company': ['tata', 'birla', 'infosys', 'ril'],
#  'projects': ('ds', 'ml', 'nlp'),
#  'best': 'abc'}

# %%
d7['company']
# Out:
# ['tata', 'birla', 'infosys', 'ril']

# %%
d7['projects']
# Out:
# ('ds', 'ml', 'nlp')

# %%
d7['best']
# Out:
# 'abc'

# %%
d7['course']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19888\2227970114.py in <module>
# ----> 1 d7['course']
#
# KeyError: 'course'

# %%
#json format data 

nested_dict = {
    'person':{'name':'john',
            'age':25,
             'address':{'street':'123 Main St',
                       'city':'Farmington',
                       'zipcode':'06032'}}
}

nested_dict
# Out:
# {'person': {'name': 'john',
#   'age': 25,
#   'address': {'street': '123 Main St',
#    'city': 'Farmington',
#    'zipcode': '06032'}}}

# %%
d8 = {'number' : [2,3,45,67,89], 'assignment':(1,2,3,5,7,8),'course':{'machinelearning':'krish','deeplearning':'youtube','nlp':'udemy'}}
print(d8)
# Out:
# {'number': [2, 3, 45, 67, 89], 'assignment': (1, 2, 3, 5, 7, 8), 'course': {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}}

# %%
d8['course']
# Out:
# {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}

# %%
d8['course']['machinelearning']
# Out:
# 'krish'

# %% [markdown]
# # Mutable

# %%
d8['mentor'] = ['rahul','bob','ruby']
print(d8)
# Out:
# {'number': [2, 3, 45, 67, 89], 'assignment': (1, 2, 3, 5, 7, 8), 'course': {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}, 'mentor': ['rahul', 'bob', 'ruby']}

# %% [markdown]
# # dict functions

# %%
# keys

dict_keys = d8.keys()
print(dict_keys)
print(type(dict_keys))
# Out:
# dict_keys(['number', 'assignment', 'course', 'mentor'])
# <class 'dict_keys'>

# %%
dict_keys1=list(dict_keys)

# %%
print(type(dict_keys1))
# Out:
# <class 'list'>

# %%
print(type(dict_keys))
# Out:
# <class 'dict_keys'>

# %%
d8.values()
# Out:
# dict_values([[2, 3, 45, 67, 89], (1, 2, 3, 5, 7, 8), {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}, ['rahul', 'bob', 'ruby']])

# %%
dict_value=list(d8.values())

# %%
print(type(dict_value))
# Out:
# <class 'list'>

# %%
d8.items()
# Out:
# dict_items([('number', [2, 3, 45, 67, 89]), ('assignment', (1, 2, 3, 5, 7, 8)), ('course', {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}), ('mentor', ['rahul', 'bob', 'ruby'])])

# %%
d8.pop('assignment')
# Out:
# (1, 2, 3, 5, 7, 8)

# %%
d8
# Out:
# {'number': [2, 3, 45, 67, 89],
#  'course': {'machinelearning': 'krish',
#   'deeplearning': 'youtube',
#   'nlp': 'udemy'},
#  'mentor': ['rahul', 'bob', 'ruby']}

# %%
d8.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19888\3144955747.py in <module>
# ----> 1 d8.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
d9 = {1:3,2:4,6:8}

# %%
d9
# Out:
# {1: 3, 2: 4, 6: 8}

# %%
d8.update(d9)
print(d8)
# Out:
# {'number': [2, 3, 45, 67, 89], 'course': {'machinelearning': 'krish', 'deeplearning': 'youtube', 'nlp': 'udemy'}, 'mentor': ['rahul', 'bob', 'ruby'], 1: 3, 2: 4, 6: 8}
