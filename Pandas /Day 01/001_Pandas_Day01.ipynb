# %% [markdown]
# # Pandas
#
# 1. Pandas is a Python library that provides extensive means for data analysis.
# 2. It allows for data manipulation in Python.
# 3. Pandas is often used for data cleaning, exploration, and analysis.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# # Reading a CSV File

# %%
df = pd.read_csv("annual.csv")

# %%
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
# head

df.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
df.head(10)
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
# 5  2011                    A  Agriculture, Forestry and Fishing          a_0
# 6  2011                    A  Agriculture, Forestry and Fishing          a_0
# 7  2011                    A  Agriculture, Forestry and Fishing          a_0
# 8  2011                    A  Agriculture, Forestry and Fishing          a_0
# 9  2011                    A  Agriculture, Forestry and Fishing        b_1-5
#
#                                           variable  value               unit
# ...

# %%
df.head(20)
# Out:
#     year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0   2011                    A  Agriculture, Forestry and Fishing          a_0
# 1   2011                    A  Agriculture, Forestry and Fishing          a_0
# 2   2011                    A  Agriculture, Forestry and Fishing          a_0
# 3   2011                    A  Agriculture, Forestry and Fishing          a_0
# 4   2011                    A  Agriculture, Forestry and Fishing          a_0
# 5   2011                    A  Agriculture, Forestry and Fishing          a_0
# 6   2011                    A  Agriculture, Forestry and Fishing          a_0
# 7   2011                    A  Agriculture, Forestry and Fishing          a_0
# 8   2011                    A  Agriculture, Forestry and Fishing          a_0
# 9   2011                    A  Agriculture, Forestry and Fishing        b_1-5
# 10  2011                    A  Agriculture, Forestry and Fishing        b_1-5
# ...

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [year, industry_code_ANZSIC, industry_name_ANZSIC, rme_size_grp, variable, value, unit]
# Index: []

# %%
# tail

df.tail()
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 17023  2021                  all       All Industries  j_Grand_Total
# 17024  2021                  all       All Industries  j_Grand_Total
# 17025  2021                  all       All Industries  j_Grand_Total
# 17026  2021                  all       All Industries  j_Grand_Total
# 17027  2021                  all       All Industries  j_Grand_Total
#
#                           variable    value               unit
# 17023                 Total income   757504  DOLLARS(millions)
# 17024            Total expenditure   654404  DOLLARS(millions)
# 17025  Operating profit before tax    85116  DOLLARS(millions)
# 17026                 Total assets  2512677  DOLLARS(millions)
# 17027        Fixed tangible assets   591351  DOLLARS(millions)

# %%
df.tail(20)
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC      rme_size_grp  \
# 17008  2021                    S       Other Services            h_200+
# 17009  2021                    S       Other Services            h_200+
# 17010  2021                    S       Other Services  i_Industry_Total
# 17011  2021                    S       Other Services  i_Industry_Total
# 17012  2021                    S       Other Services  i_Industry_Total
# 17013  2021                    S       Other Services  i_Industry_Total
# 17014  2021                    S       Other Services  i_Industry_Total
# 17015  2021                    S       Other Services  i_Industry_Total
# 17016  2021                    S       Other Services  i_Industry_Total
# 17017  2021                    S       Other Services  i_Industry_Total
# 17018  2021                    S       Other Services  i_Industry_Total
# 17019  2021                  all       All Industries     j_Grand_Total
# ...

# %%
#type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['year', 'industry_code_ANZSIC', 'industry_name_ANZSIC', 'rme_size_grp',
#        'variable', 'value', 'unit'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['year',
#  'industry_code_ANZSIC',
#  'industry_name_ANZSIC',
#  'rme_size_grp',
#  'variable',
#  'value',
#  'unit']

# %%
df['unit']
# Out:
# 0                    COUNT
# 1                    COUNT
# 2        DOLLARS(millions)
# 3        DOLLARS(millions)
# 4        DOLLARS(millions)
#                ...
# 17023    DOLLARS(millions)
# 17024    DOLLARS(millions)
# 17025    DOLLARS(millions)
# 17026    DOLLARS(millions)
# 17027    DOLLARS(millions)
# Name: unit, Length: 17028, dtype: object

# %%
df['year']
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
#          ...
# 17023    2021
# 17024    2021
# 17025    2021
# 17026    2021
# 17027    2021
# Name: year, Length: 17028, dtype: int64

# %%
type(df['unit'])
# Out:
# pandas.core.series.Series

# %%
type(df['year'])   # []--1- D array ---Series is one dimensional array
# Out:
# pandas.core.series.Series

# %%
df['value','variable']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('value', 'variable')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
d2=df[['value','variable']] # [[]]----2-D array

# %%
d2
# Out:
#          value                                         variable
# 0        46134                                    Activity unit
# 1            0                           Rolling mean employees
# 2          279                          Salaries and wages paid
# 3         8187  Sales, government funding, grants and subsidies
# 4         8866                                     Total income
# ...        ...                                              ...
# 17023   757504                                     Total income
# 17024   654404                                Total expenditure
# 17025    85116                      Operating profit before tax
# 17026  2512677                                     Total assets
# 17027   591351                            Fixed tangible assets
#
# [17028 rows x 2 columns]

# %%
type(d2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['unit']])
# Out:
# pandas.core.frame.DataFrame

# %%
list(df['unit'])
# Out:
# ['COUNT',
#  'COUNT',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'COUNT',
#  'COUNT',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'COUNT',
#  'COUNT',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'COUNT',
#  'COUNT',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'COUNT',
#  'COUNT',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'DOLLARS(millions)',
#  'COUNT',
#  'COUNT',
# ...

# %%
df['unit']
# Out:
# 0                    COUNT
# 1                    COUNT
# 2        DOLLARS(millions)
# 3        DOLLARS(millions)
# 4        DOLLARS(millions)
#                ...
# 17023    DOLLARS(millions)
# 17024    DOLLARS(millions)
# 17025    DOLLARS(millions)
# 17026    DOLLARS(millions)
# 17027    DOLLARS(millions)
# Name: unit, Length: 17028, dtype: object

# %%
df.dtypes
#object = string
# Out:
# year                     int64
# industry_code_ANZSIC    object
# industry_name_ANZSIC    object
# rme_size_grp            object
# variable                object
# value                   object
# unit                    object
# dtype: object

# %%
df[['year','value','variable','rme_size_grp']]
# Out:
#        year    value                                         variable  \
# 0      2011    46134                                    Activity unit
# 1      2011        0                           Rolling mean employees
# 2      2011      279                          Salaries and wages paid
# 3      2011     8187  Sales, government funding, grants and subsidies
# 4      2011     8866                                     Total income
# ...     ...      ...                                              ...
# 17023  2021   757504                                     Total income
# 17024  2021   654404                                Total expenditure
# 17025  2021    85116                      Operating profit before tax
# 17026  2021  2512677                                     Total assets
# 17027  2021   591351                            Fixed tangible assets
#
#         rme_size_grp
# 0                a_0
# 1                a_0
# 2                a_0
# 3                a_0
# ...

# %% [markdown]
# # Reading a Excel file

# %%
df1 = pd.read_excel('Jan_data.xlsx')

# %%
df1
# Out:
#     January Month Expenses  Unnamed: 1           Unnamed: 2  \
# 0                      NaN         NaN                  NaN
# 1                      NaN         NaN                  NaN
# 2                      NaN         NaN                 Date
# 3                      NaN         NaN  2023-01-01 00:00:00
# 4                      NaN         NaN  2023-01-02 00:00:00
# 5                      NaN         NaN  2023-01-03 00:00:00
# 6                      NaN         NaN  2023-01-04 00:00:00
# 7                      NaN         NaN  2023-01-05 00:00:00
# 8                      NaN         NaN  2023-01-06 00:00:00
# 9                      NaN         NaN  2023-01-07 00:00:00
# 10                     NaN         NaN  2023-01-08 00:00:00
# 11                     NaN         NaN  2023-01-09 00:00:00
# 12                     NaN         NaN  2023-01-10 00:00:00
# 13                     NaN         NaN  2023-01-11 00:00:00
# 14                     NaN         NaN  2023-01-12 00:00:00
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# January Month Expenses    float64
# Unnamed: 1                float64
# Unnamed: 2                 object
# Unnamed: 3                 object
# Unnamed: 4                 object
# Unnamed: 5                 object
# Unnamed: 6                 object
# Unnamed: 7                float64
# Unnamed: 8                float64
# Unnamed: 9                float64
# Unnamed: 10               float64
# Unnamed: 11               float64
# Unnamed: 12                object
# Unnamed: 13                object
# Unnamed: 14                object
# dtype: object

# %%
df1.columns
# Out:
# Index(['January Month Expenses', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
df1[['January Month Expenses','Unnamed: 1','Unnamed: 7']]
# Out:
#     January Month Expenses  Unnamed: 1  Unnamed: 7
# 0                      NaN         NaN         NaN
# 1                      NaN         NaN         NaN
# 2                      NaN         NaN         NaN
# 3                      NaN         NaN         NaN
# 4                      NaN         NaN         NaN
# 5                      NaN         NaN         NaN
# 6                      NaN         NaN         NaN
# 7                      NaN         NaN         NaN
# 8                      NaN         NaN         NaN
# 9                      NaN         NaN         NaN
# 10                     NaN         NaN         NaN
# 11                     NaN         NaN         NaN
# 12                     NaN         NaN         NaN
# 13                     NaN         NaN         NaN
# 14                     NaN         NaN         NaN
# 15                     NaN         NaN         NaN
# 16                     NaN         NaN         NaN
# ...

# %%
df1['Unnamed: 9']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# Name: Unnamed: 9, dtype: float64

# %%
df2 = pd.read_csv("https://media.githubusercontent.com/media/datablist/sample-csv-files/main/files/organizations/organizations-100.csv")

# %%
df2
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
df2.head(3)
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
#
#                            Description  Founded                     Industry  \
# 0  Horizontal empowering knowledgebase     1990                     Plastics
# 1  User-centric system-worthy leverage     2015  Glass / Ceramics / Concrete
# 2       Switchable scalable moratorium     1971                Public Safety
#
#    Number of employees
# 0                 3498
# 1                 4952
# 2                 5287

# %%
df2.tail(3)
# Out:
#     Index  Organization Id               Name                  Website  \
# 97     98  E7df80C60Abd7f9  Clements-Espinoza  http://www.flowers.net/
# 98     99  AFc285dbE2fEd24         Mendez Inc   https://www.burke.net/
# 99    100  e9eB5A60Cef8354     Watkins-Kaiser  http://www.herring.com/
#
#                         Country                      Description  Founded  \
# 97  Falkland Islands (Malvinas)          Progressive modular hub     1991
# 98              Kyrgyz Republic  User-friendly exuding migration     1993
# 99                         Togo    Synergistic background access     2009
#
#                 Industry  Number of employees
# 97       Broadcast Media                  236
# 98  Education Management                  339
# 99    Financial Services                 2785

# %%
df2.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2['Website']
# Out:
# 0                 https://price.net/
# 1     http://www.hall-buchanan.info/
# 2          http://sullivan-reed.com/
# 3                https://becker.com/
# 4             http://www.brewer.com/
#                    ...
# 95             https://mcdowell.org/
# 96                 http://duffy.com/
# 97           http://www.flowers.net/
# 98            https://www.burke.net/
# 99           http://www.herring.com/
# Name: Website, Length: 100, dtype: object

# %%
df2[['Index','Name','Country']]
# Out:
#     Index                     Name                      Country
# 0       1              Ferrell LLC             Papua New Guinea
# 1       2  Mckinney, Riley and Day                      Finland
# 2       3               Hester Ltd                        China
# 3       4           Holder-Sellers                 Turkmenistan
# 4       5              Mayer Group                    Mauritius
# ..    ...                      ...                          ...
# 95     96             Holmes Group                     Ethiopia
# 96     97                 Good Ltd                     Anguilla
# 97     98        Clements-Espinoza  Falkland Islands (Malvinas)
# 98     99               Mendez Inc              Kyrgyz Republic
# 99    100           Watkins-Kaiser                         Togo
#
# [100 rows x 3 columns]

# %% [markdown]
# # reading html data

# %%
df3 = pd.read_html("https://en.wikipedia.org/wiki/Economy_of_the_United_States")

# %%
df3
# Out:
# [                                                    0  \
#  0   New York City, the world’s principal financial...
#  1                                            Currency
#  2                                         Fiscal year
#  3                                 Trade organizations
#  4                                       Country group
#  5                                          Statistics
#  6                                          Population
#  7                                                 GDP
#  8                                            GDP rank
#  9                                          GDP growth
#  10                                     GDP per capita
#  11                                GDP per capita rank
#  12                                      GDP by sector
#  13                                   GDP by component
#  14                                    Inflation (CPI)
#  15                      Population below poverty line
# ...

# %%
len(df3)
# Out:
# 13

# %%
html_data = df3[3]

# %%
html_data
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                2857.3                      12552.9
# 1   1981                3207.0                      13948.7
# 2   1982                3343.8                      14405.0
# 3   1983                3634.0                      15513.7
# 4   1984                4037.7                      17086.4
# 5   1985                4339.0                      18199.3
# 6   1986                4579.6                      19034.8
# 7   1987                4855.3                      20001.0
# 8   1988                5236.4                      21376.0
# 9   1989                5641.6                      22814.1
# 10  1990                5963.1                      23848.0
# 11  1991                6158.1                      24302.8
# 12  1992                6520.3                      25392.9
# 13  1993                6858.6                      26364.2
# 14  1994                7287.3                      27674.0
# ...

# %%
type(html_data)
# Out:
# pandas.core.frame.DataFrame

# %%
html_data.to_csv("US_GDP.csv",index=False)
